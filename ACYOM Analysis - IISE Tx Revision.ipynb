# %% [markdown]
# # Churn rate

# %%
import matplotlib.pyplot as plt

# Data from the provided table
years = [1, 2, 3, 4, 5]
C0D2 = [2.557784565, 2.079444949, 1.642933783, 1.244886758, 0.882206068]
C3D1_P_CR_1 = [-9.941624659, -1.185212046, 1.389500054, 2.44682135, 2.917380241]
C3D1_S_CR_1 = [-3.953203746, 0.663946441, 1.928301488, 2.377760455, 2.518013728]
C3D1_P_CR_2 = [-10.33411995, -1.559866643, 1.031604898, 2.104678102, 2.590049729]
C3D1_S_CR_2 = [-4.345699038, 0.289291844, 1.570406332, 2.035617207, 2.190683216]
C3D1_P_CR_3 = [-10.72661524, -1.93452124, 0.673709742, 1.762534855, 2.262719218]
C3D1_S_CR_3 = [-4.73819433, -0.085362753, 1.212511176, 1.69347396, 1.863352705]
C3D1_P_CR_4 = [-11.11911054, -2.309175838, 0.315814585, 1.420391607, 1.935388707]
C3D1_S_CR_4 = [-5.130689622, -0.46001735, 0.85461602, 1.351330712, 1.536022194]

# Plot
plt.figure(figsize=(10, 6))

# Plot lines
plt.plot(years, C0D2, linestyle='-', marker='o', markersize=5, color='black', alpha=0.8, label='C0D2')
plt.plot(years, C3D1_P_CR_1, linestyle='--', marker='^', markersize=8, color='blue', alpha=0.5, label='C3D1:P(CR=1%)')
plt.plot(years, C3D1_S_CR_1, linestyle='-', marker='s', markersize=8, color='blue', alpha=0.5, label='C3D1:S(CR=1%)')

plt.plot(years, C3D1_P_CR_2, linestyle='--', marker='^', markersize=8, color='orange', alpha=0.5, label='C3D1:P(CR=2%)')
plt.plot(years, C3D1_S_CR_2, linestyle='-', marker='s', markersize=8, color='orange', alpha=0.5, label='C3D1:S(CR=2%)')

plt.plot(years, C3D1_P_CR_3, linestyle='--', marker='^', markersize=8, color='green', alpha=0.5, label='C3D1:P(CR=3%)')
plt.plot(years, C3D1_S_CR_3, linestyle='-', marker='s', markersize=8, color='green', alpha=0.5, label='C3D1:S(CR=3%)')

plt.plot(years, C3D1_P_CR_4, linestyle='--', marker='^', markersize=8, color='red', alpha=0.5, label='C3D1:P(CR=4%)')
plt.plot(years, C3D1_S_CR_4, linestyle='-', marker='s', markersize=8, color='red', alpha=0.5, label='C3D1:S(CR=4%)')

# Add a horizontal line at y = 0
plt.axhline(y=0, color='gray', linestyle='-', linewidth=3, alpha=0.5)

# Title and labels
plt.xlabel('Year of operation', fontsize=15)
plt.ylabel('Avg. cumulative yearly operating margin ($\\nabla$)\n per 30 minute wave in USD', fontsize=15)

# Increase font size of axis ticks
plt.xticks(ticks=years, fontsize=12)  # Show only integer values from 1 to 5
plt.yticks(fontsize=12)

# Legend
plt.legend(fontsize=14, loc='lower right')

# Save the figure in high resolution
plt.savefig('V2CR_updated.png', dpi=300, bbox_inches='tight')

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Compensation level

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# Updated data lists
years = [1, 2, 3, 4, 5]
C0D2 = [2.557784565, 2.079444949, 1.642933783, 1.244886758, 0.882206068]
C3D1_P_CPP_0_06 = [-6.806657349, 1.80725675, 4.24810661, 5.179613102, 5.531858613]
C3D1_S_CPP_0_06 = [-0.818236435, 3.656415237, 4.786908044, 5.110552207, 5.1324921]
C3D1_P_CPP_0_12 = [-9.941624659, -1.185212046, 1.389500054, 2.44682135, 2.917380241]
C3D1_S_CPP_0_12 = [-3.953203746, 0.663946441, 1.928301488, 2.377760455, 2.518013728]
C3D1_P_CPP_0_18 = [-13.07659197, -4.177680843, -1.469106502, -0.285970402, 0.302901868]
C3D1_S_CPP_0_18 = [-7.088171056, -2.328522355, -0.930305067, -0.355031297, -0.096464645]
C3D1_P_CPP_0_24 = [-11.11911054, -2.309175838, 0.315814585, 1.420391607, 1.935388707]
C3D1_S_CPP_0_24 = [-5.130689622, -0.46001735, 0.85461602, 1.351330712, 1.536022194]

# Plot
plt.figure(figsize=(10, 6))

# Plot lines
plt.plot(years, C0D2, linestyle='-', marker='o', markersize=5, color='black', alpha=0.8, label='C0D2')
plt.plot(years, C3D1_P_CPP_0_06, linestyle='--', marker='^', markersize=8, color='blue', alpha=0.5, label='C3D1:P(CPP=$0.06)')
plt.plot(years, C3D1_S_CPP_0_06, linestyle='-', marker='s', markersize=8, color='blue', alpha=0.5, label='C3D1:S(CPP=$0.06)')

plt.plot(years, C3D1_P_CPP_0_12, linestyle='--', marker='^', markersize=8, color='orange', alpha=0.5, label='C3D1:P(CPP=$0.12)')
plt.plot(years, C3D1_S_CPP_0_12, linestyle='-', marker='s', markersize=8, color='orange', alpha=0.5, label='C3D1:S(CPP=$0.12)')

plt.plot(years, C3D1_P_CPP_0_18, linestyle='--', marker='^', markersize=8, color='green', alpha=0.5, label='C3D1:P(CPP=$0.18)')
plt.plot(years, C3D1_S_CPP_0_18, linestyle='-', marker='s', markersize=8, color='green', alpha=0.5, label='C3D1:S(CPP=$0.18)')

plt.plot(years, C3D1_P_CPP_0_24, linestyle='--', marker='^', markersize=8, color='red', alpha=0.5, label='C3D1:P(CPP=$0.24)')
plt.plot(years, C3D1_S_CPP_0_24, linestyle='-', marker='s', markersize=8, color='red', alpha=0.5, label='C3D1:S(CPP=$0.24)')

# Add a horizontal line at y = 0
plt.axhline(y=0, color='gray', linestyle='-', linewidth=3, alpha=0.5)

# Title and labels
plt.xlabel('Year of operation', fontsize=15)
plt.ylabel('Avg. cumulative yearly operating margin ($\\nabla$)\n per 30 minute wave in USD', fontsize=15)

# Increase font size of axis ticks
plt.xticks(ticks=years, fontsize=12)  # Show only integer values from 1 to 5
plt.yticks(fontsize=12)

# Legend
plt.legend(fontsize=14, loc='lower right')

# Save the figure in high resolution
plt.savefig('V2CPP_updated.png', dpi=300, bbox_inches='tight')

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Participation levels

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# Updated data lists
years = [1, 2, 3, 4, 5]
C0D2 = [2.557784565, 2.079444949, 1.642933783, 1.244886758, 0.882206068]
C3D1_P_f_52 = [-10.09049332, -1.32731395, 1.253754801, 2.317050603, 2.793227783]
C3D1_S_f_52 = [-4.102072407, 0.521844537, 1.792556235, 2.247989708, 2.39386127]
C3D1_P_f_65 = [-9.949280471, -1.192519867, 1.382519134, 2.440147679, 2.910995499]
C3D1_S_f_65 = [-3.960859558, 0.65663862, 1.921320569, 2.371086784, 2.511628986]
C3D1_P_f_78 = [-9.941624659, -1.185212046, 1.389500054, 2.44682135, 2.917380241]
C3D1_S_f_78 = [-3.953203746, 0.663946441, 1.928301488, 2.377760455, 2.518013728]
C3D1_P_f_91 = [-9.771575555, -1.022892447, 1.544558603, 2.595055364, 3.059196617]
C3D1_S_f_91 = [-3.783154642, 0.82626604, 2.083360038, 2.525994469, 2.659830104]

# Plot
plt.figure(figsize=(10, 6))

# Plot lines
plt.plot(years, C0D2, linestyle='-', marker='o', markersize=5, color='black', alpha=0.8, label='C0D2')
plt.plot(years, C3D1_P_f_52, linestyle='--', marker='^', markersize=8, color='blue', alpha=0.5, label='C3D1:P(f=52%)')
plt.plot(years, C3D1_S_f_52, linestyle='-', marker='s', markersize=8, color='blue', alpha=0.5, label='C3D1:S(f=52%)')

plt.plot(years, C3D1_P_f_65, linestyle='--', marker='^', markersize=8, color='orange', alpha=0.5, label='C3D1:P(f=65%)')
plt.plot(years, C3D1_S_f_65, linestyle='-', marker='s', markersize=8, color='orange', alpha=0.5, label='C3D1:S(f=65%)')

plt.plot(years, C3D1_P_f_78, linestyle='--', marker='^', markersize=8, color='green', alpha=0.5, label='C3D1:P(f=78%)')
plt.plot(years, C3D1_S_f_78, linestyle='-', marker='s', markersize=8, color='green', alpha=0.5, label='C3D1:S(f=78%)')

plt.plot(years, C3D1_P_f_91, linestyle='--', marker='^', markersize=8, color='red', alpha=0.5, label='C3D1:P(f=91%)')
plt.plot(years, C3D1_S_f_91, linestyle='-', marker='s', markersize=8, color='red', alpha=0.5, label='C3D1:S(f=91%)')

# Add a horizontal line at y = 0
plt.axhline(y=0, color='gray', linestyle='-', linewidth=3, alpha=0.5)

# Title and labels
plt.xlabel('Year of operation', fontsize=15)
plt.ylabel('Avg. cumulative yearly operating margin ($\\nabla$)\n per 30 minute wave in USD', fontsize=15)

# Increase font size of axis ticks
plt.xticks(ticks=years, fontsize=12)  # Show only integer values from 1 to 5
plt.yticks(fontsize=12)

# Legend
plt.legend(fontsize=14, loc='lower right')

# Save the figure in high resolution
plt.savefig('V2f_updated.png', dpi=300, bbox_inches='tight')

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Non-deployement of AMRs: P: CR=1%

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# Updated data lists
years = [1, 2, 3, 4, 5, 6, 7]
C0D2 = [2.557784565, 2.079444949, 1.642933783, 1.244886758, 0.882206068, 0.552039249, 0.251759711]
C3D1_Purchase = [-9.941624659, -1.185212046, 1.389500054, 2.44682135, 2.917380241, 3.10970275, 3.154709553]
C3D1_300_plus = [-10.69287232, -1.917520832, 0.675521594, 1.750584633, 2.238316118, 2.447260972, 2.508358237]
C3D1_250_plus = [-12.53458972, -3.718126378, -1.084953172, 0.029266186, 0.555188222, 0.801368367, 0.898757738]
C3D1_200_plus = [-14.32203181, -5.466923682, -2.795937237, -1.644739775, -1.082675534, -0.80118734, -0.669320135]
C3D1_150_plus = [-15.00968144, -6.144608754, -3.463506698, -2.302083008, -1.729718125, -1.437887236, -1.295664138]
C3D1_100_plus = [-15.68945078, -6.814771725, -4.123890545, -2.952556885, -2.370188762, -2.068294996, -1.915979422]

# Plot
plt.figure(figsize=(10, 6))

# Plot lines
plt.plot(years, C0D2, linestyle='-', marker='o', markersize=5, color='black', alpha=0.8, label='C0D2')
plt.plot(years, C3D1_Purchase, linestyle='-', marker='o', markersize=8, color='blue', alpha=0.5, label='C3D1:P')
plt.plot(years, C3D1_300_plus, linestyle='--', marker='^', markersize=8, color='orange', alpha=0.5, label='C3D1:P(300+)')
plt.plot(years, C3D1_250_plus, linestyle='--', marker='^', markersize=8, color='green', alpha=0.5, label='C3D1:P(250+)')
plt.plot(years, C3D1_200_plus, linestyle='--', marker='^', markersize=8, color='red', alpha=0.5, label='C3D1:P(200+)')
plt.plot(years, C3D1_150_plus, linestyle='--', marker='^', markersize=8, color='purple', alpha=0.5, label='C3D1:P(150+)')

# Add a horizontal line at y = 0
plt.axhline(y=0, color='gray', linestyle='-', linewidth=3, alpha=0.7)

# Title and labels
plt.xlabel('Year of operation', fontsize=15)
plt.ylabel('Avg. cumulative yearly operating margin ($\\nabla$)\n per 30 minute wave in USD', fontsize=15)

# Increase font size of axis ticks
plt.xticks(ticks=years, fontsize=12)  # Show only integer values from 1 to 7
plt.yticks(fontsize=12)

# Legend
plt.legend(fontsize=14, loc='lower right')

# Save the figure in high resolution
plt.savefig('V2non-depl-p-cr-1_updated.png', dpi=300, bbox_inches='tight')

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Non-deployement of AMRs: S: CR=1%

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# Updated data lists
years = [1, 2, 3, 4, 5, 6, 7]
C0D2 = [2.557784565, 2.079444949, 1.642933783, 1.244886758, 0.882206068, 0.552039249, 0.251759711]
C3D1_Subscription = [-3.953203746, 0.663946441, 1.928301488, 2.377760455, 2.518013728, 2.516202021, 2.442855448]
C3D1_300_plus = [-4.704451412, -0.068362345, 1.214323028, 1.681523738, 1.838949605, 1.853760244, 1.796504132]
C3D1_250_plus = [-6.546168802, -1.868967891, -0.546151738, -0.039794709, 0.155821709, 0.207867639, 0.186903633]
C3D1_200_plus = [-8.333610892, -3.617765195, -2.257135802, -1.71380067, -1.482042047, -1.394688069, -1.38117424]
C3D1_150_plus = [-9.021260528, -4.295450267, -2.924705264, -2.371143903, -2.129084638, -2.031387965, -2.007518244]

# Plot
plt.figure(figsize=(10, 6))

# Plot lines
plt.plot(years, C0D2, linestyle='-', marker='o', markersize=5, color='black', alpha=0.8, label='C0D2')
plt.plot(years, C3D1_Subscription, linestyle='-', marker='o', markersize=8, color='blue', alpha=0.5, label='C3D1:S')
plt.plot(years, C3D1_300_plus, linestyle='--', marker='^', markersize=8, color='orange', alpha=0.5, label='C3D1:S(300+)')
plt.plot(years, C3D1_250_plus, linestyle='--', marker='^', markersize=8, color='green', alpha=0.5, label='C3D1:S(250+)')
plt.plot(years, C3D1_200_plus, linestyle='--', marker='^', markersize=8, color='red', alpha=0.5, label='C3D1:S(200+)')
plt.plot(years, C3D1_150_plus, linestyle='--', marker='^', markersize=8, color='purple', alpha=0.5, label='C3D1:S(150+)')

# Add a horizontal line at y = 0
plt.axhline(y=0, color='gray', linestyle='-', linewidth=3, alpha=0.7)

# Title and labels
plt.xlabel('Year of operation', fontsize=15)
plt.ylabel('Avg. cumulative yearly operating margin ($\\nabla$)\n per 30 minute wave in USD', fontsize=15)

# Increase font size of axis ticks
plt.xticks(ticks=years, fontsize=12)  # Show only integer values from 1 to 7
plt.yticks(fontsize=12)

# Legend
plt.legend(fontsize=14, loc='lower right')

# Save the figure in high resolution
plt.savefig('V2non-depl-s-cr-1_updated.png', dpi=300, bbox_inches='tight')

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Non-deployement of AMRs: P: CR=4%

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# Updated data lists
years = [1, 2, 3, 4, 5, 6, 7]
C0D2 = [2.557784565, 2.079444949, 1.642933783, 1.244886758, 0.882206068, 0.552039249, 0.251759711]
C3D1_Purchase = [-11.11911054, -2.309175838, 0.315814585, 1.420391607, 1.935388707, 2.169522123, 2.253889005]
C3D1_300_plus = [-11.65139133, -2.832470795, -0.198499871, 0.915031155, 1.438937059, 1.681917608, 1.775055498]
C3D1_250_plus = [-12.98658615, -4.149577523, -1.497104193, -0.364744983, 0.178235357, 0.440465275, 0.55296363]
C3D1_200_plus = [-14.34843254, -5.49212438, -2.820010631, -1.667753636, -1.104693033, -0.822267386, -0.689517678]
C3D1_150_plus = [-15.00968144, -6.144608754, -3.463506698, -2.302083008, -1.729718125, -1.437887236, -1.295664138]

# Plot
plt.figure(figsize=(10, 6))

# Plot lines
plt.plot(years, C0D2, linestyle='-', marker='o', markersize=5, color='black', alpha=0.8, label='C0D2')
plt.plot(years, C3D1_Purchase, linestyle='-', marker='o', markersize=8, color='blue', alpha=0.5, label='C3D1:P')
plt.plot(years, C3D1_300_plus, linestyle='--', marker='^', markersize=8, color='orange', alpha=0.5, label='C3D1:P(300+)')
plt.plot(years, C3D1_250_plus, linestyle='--', marker='^', markersize=8, color='green', alpha=0.5, label='C3D1:P(250+)')
plt.plot(years, C3D1_200_plus, linestyle='--', marker='^', markersize=8, color='red', alpha=0.5, label='C3D1:P(200+)')
plt.plot(years, C3D1_150_plus, linestyle='--', marker='^', markersize=8, color='purple', alpha=0.5, label='C3D1:P(150+)')

# Add a horizontal line at y = 0
plt.axhline(y=0, color='gray', linestyle='-', linewidth=3, alpha=0.7)

# Title and labels
plt.xlabel('Year of operation', fontsize=15)
plt.ylabel('Avg. cumulative yearly operating margin ($\\nabla$)\n per 30 minute wave in USD', fontsize=15)

# Increase font size of axis ticks
plt.xticks(ticks=years, fontsize=12)  # Show only integer values from 1 to 7
plt.yticks(fontsize=12)

# Legend
plt.legend(fontsize=14, loc='lower right')

# Save the figure in high resolution
plt.savefig('V2-non-depl-p-cr-4_updated.png', dpi=300, bbox_inches='tight')

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Non-deployement of AMRs: S: CR=4%

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# Updated data lists
years = [1, 2, 3, 4, 5, 6, 7]
C0D2 = [2.557784565, 2.079444949, 1.642933783, 1.244886758, 0.882206068, 0.552039249, 0.251759711]
C3D1_Subscription = [-5.130689622, -0.46001735, 0.85461602, 1.351330712, 1.536022194, 1.576021395, 1.5420349]
C3D1_300_plus = [-5.66297042, -0.983312308, 0.340301563, 0.84597026, 1.039570546, 1.08841688, 1.063201393]
C3D1_250_plus = [-6.99816524, -2.300419035, -0.958302759, -0.433805878, -0.221131156, -0.153035453, -0.158890475]
C3D1_200_plus = [-8.360011623, -3.642965893, -2.281209196, -1.736814531, -1.504059546, -1.415768114, -1.401371783]
C3D1_150_plus = [-9.021260528, -4.295450267, -2.924705264, -2.371143903, -2.129084638, -2.031387965, -2.007518244]
C3D1_100_plus = [-9.701029867, -4.965613238, -3.585089111, -3.02161778, -2.769555275, -2.661795724, -2.627833527]

# Plot
plt.figure(figsize=(10, 6))

# Plot lines
plt.plot(years, C0D2, linestyle='-', marker='o', markersize=5, color='black', alpha=0.8, label='C0D2')
plt.plot(years, C3D1_Subscription, linestyle='-', marker='o', markersize=8, color='blue', alpha=0.5, label='C3D1:S')
plt.plot(years, C3D1_300_plus, linestyle='--', marker='^', markersize=8, color='orange', alpha=0.5, label='C3D1:S(300+)')
plt.plot(years, C3D1_250_plus, linestyle='--', marker='^', markersize=8, color='green', alpha=0.5, label='C3D1:S(250+)')
plt.plot(years, C3D1_200_plus, linestyle='--', marker='^', markersize=8, color='red', alpha=0.5, label='C3D1:S(200+)')
plt.plot(years, C3D1_150_plus, linestyle='--', marker='^', markersize=8, color='purple', alpha=0.5, label='C3D1:S(150+)')
plt.plot(years, C3D1_100_plus, linestyle='--', marker='^', markersize=8, color='magenta', alpha=0.5, label='C3D1:S(100+)')

# Add a horizontal line at y = 0
plt.axhline(y=0, color='gray', linestyle='-', linewidth=3, alpha=0.7)

# Title and labels
plt.xlabel('Year of operation', fontsize=15)
plt.ylabel('Avg. cumulative yearly operating margin ($\\nabla$)\n per 30 minute wave in USD', fontsize=15)

# Increase font size of axis ticks
plt.xticks(ticks=years, fontsize=12)  # Show only integer values from 1 to 7
plt.yticks(fontsize=12)

# Legend
plt.legend(fontsize=14, loc='lower right')

# Save the figure in high resolution
plt.savefig('V2-non-depl-s-cr-4_updated.png', dpi=300, bbox_inches='tight')

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Instance wise comparison - 5 years

# %%
import matplotlib.pyplot as plt
import numpy as np

# Updated Data
instances = np.arange(1, 11)
C0D2 = [-4.554786977, -1.712606689, -1.598352193, -0.652257801, -0.208509136, 0.882206068, -1.725836507, 0.367979441, -5.307408743, -4.420923106]
C3D1_purchase = [-2.906640909, -0.781436923, 0.934628897, 1.009191231, 1.746687464, 2.917380241, 1.505782863, 5.196332881, 2.436012955, 3.534999067]
C3D1_subscription = [-3.306007421, -1.180803436, 0.535262384, 0.609824718, 1.347320951, 2.518013728, 1.10641635, 4.796966368, 2.036646442, 3.135632554]

bar_width = 0.25  # Width of the bars
index = np.arange(len(instances))  # The label locations

# Plotting
fig, ax = plt.subplots(figsize=(10, 7))

bars1 = ax.bar(index - bar_width, C0D2, bar_width, label='C0D2', color='salmon')  # Salmon color
bars2 = ax.bar(index, C3D1_purchase, bar_width, label='C3D1 (Purchase)', color='lightgreen')  # Light green color
bars3 = ax.bar(index + bar_width, C3D1_subscription, bar_width, label='C3D1 (Subscription)', color='skyblue')  # Light blue color

# Labels, title, and legend
ax.set_xlabel('Order Instance Number', fontsize=15)
ax.set_ylabel('Avg. cumulative yearly operating margin ($\\nabla$)\n per 30 minute wave in USD', fontsize=15)
# ax.set_title('Bar Plot of Data by Instance', fontsize=14)
ax.set_xticks(index)
ax.set_xticklabels(instances, fontsize=15)
ax.legend(fontsize=15)

# Set y-axis tick label size
ax.tick_params(axis='y', labelsize=15)

# Save the figure in high resolution
plt.savefig('V2acyom_5years_updated.png', dpi=300, bbox_inches='tight')

# Show plot
plt.tight_layout()
plt.show()
