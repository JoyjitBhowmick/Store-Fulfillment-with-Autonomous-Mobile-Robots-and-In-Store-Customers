# %% [markdown]
# # Subscription Model - Impact of Hassle Cost

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# Data
years = list(range(6))
C0D2_1 = [0, 331634.7395, 642059.261, 932726.3724, 1204982.106, 1460074.076]
C3D1_1 = [125420, 362817.0607, 583116.9586, 787635.4834, 977581.4984, 1154065.985]
C0D2_2 = [0, 346605.3706, 1003635.263, 1951332.266, 3171285.003, 4646329.71]
C3D1_2 = [125420, 376426.7254, 609099.0456, 824865.2271, 1025036.385, 1210816.456]
C0D2_3 = [0, 361576.0017, 1033576.525, 1996244.16, 3231167.527, 4721182.865]
C3D1_3 = [125420, 390036.39, 635081.1327, 862094.9709, 1072491.271, 1267566.926]
C0D2_4 = [0, 376546.6328, 1063517.787, 2041156.053, 3291050.052, 4796036.021]
C3D1_4 = [125420, 403646.0546, 661063.2197, 899324.7147, 1119946.157, 1324317.396]

# Plot
plt.figure(figsize=(10, 6))

# Plot lines
plt.plot(years, C0D2_1, linestyle='-', marker='o', markersize=5, color='black', alpha=0.6, label='C0D2')
plt.plot(years, C3D1_1, linestyle='--', marker='^', markersize=8, color='blue', alpha=0.6, label='C3D1(CR=1%)')
#plt.plot(years, C0D2_2, linestyle='-', marker='o', markersize=5, color='orange', alpha=0.5, label='C0D2(CR=2%)')
plt.plot(years, C3D1_2, linestyle='--', marker='^', markersize=8, color='orange', alpha=0.6, label='C3D1(CR=2%)')
#plt.plot(years, C0D2_3, linestyle='-', marker='o', markersize=5, color='green', alpha=0.5, label='C0D2(CR=3%)')
plt.plot(years, C3D1_3, linestyle='--', marker='^', markersize=8, color='green', alpha=0.6, label='C3D1(CR=3%)')
#plt.plot(years, C0D2_4, linestyle='-', marker='o', markersize=5, color='red', alpha=0.5, label='C0D2(CR=4%)')
plt.plot(years, C3D1_4, linestyle='--', marker='^', markersize=8, color='red', alpha=0.6, label='C3D1(CR=4%)')

# Title and labels
plt.title('Subscription Model - Impact of Churn Rate Levels', fontsize=16)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Risk-adjusted cumulative cost in USD', fontsize=15)

# Format y-axis tick labels as millions
def millions_formatter(x, pos):
    return f'{x / 1e6:.1f}M'

formatter = FuncFormatter(millions_formatter)
plt.gca().yaxis.set_major_formatter(formatter)

# Increase font size of axis ticks
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Legend
plt.legend(fontsize=15, loc='upper left')

# Save the figure in high resolution
plt.savefig('Subscription Model - Impact of Churn Rate.png', dpi=300, bbox_inches='tight')

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Purchase Model - Impact of Hassle Cost

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# Data
years = list(range(6))
C0D2_1 = [0, 331634.7395, 642059.261, 932726.3724, 1204982.106, 1460074.076]
C3D1_1 = [230840, 437146.1516, 629181.5867, 808005.1453, 974592.1001, 1129841.078]
C0D2_2 = [0, 346605.3706, 1003635.263, 1951332.266, 3171285.003, 4646329.71]
C3D1_2 = [230840, 450755.8163, 655163.6737, 845234.889, 1022046.986, 1186591.548]
C0D2_3 = [0, 361576.0017, 1033576.525, 1996244.16, 3231167.527, 4721182.865]
C3D1_3 = [230840, 464365.4809, 676661.3726, 869657.6378, 1045108.788, 1204609.834]
C0D2_4 = [0, 376546.6328, 1063517.787, 2041156.053, 3291050.052, 4796036.021]
C3D1_4 = [230840, 477975.1455, 707127.8478, 919694.3766, 1116956.759, 1300092.489]

# Plot
plt.figure(figsize=(10, 6))

# Plot lines
plt.plot(years, C0D2_1, linestyle='-', marker='o', markersize=5, color='black', alpha=0.6, label='C0D2')
plt.plot(years, C3D1_1, linestyle='--', marker='^', markersize=8, color='blue', alpha=0.6, label='C3D1(CR=1%)')
#plt.plot(years, C0D2_2, linestyle='-', marker='o', markersize=5, color='orange', alpha=0.5, label='C0D2(CR=2%)')
plt.plot(years, C3D1_2, linestyle='--', marker='^', markersize=8, color='orange', alpha=0.6, label='C3D1(CR=2%)')
#plt.plot(years, C0D2_3, linestyle='-', marker='o', markersize=5, color='green', alpha=0.5, label='C0D2(CR=3%)')
plt.plot(years, C3D1_3, linestyle='--', marker='^', markersize=8, color='green', alpha=0.6, label='C3D1(CR=3%)')
#plt.plot(years, C0D2_4, linestyle='-', marker='o', markersize=5, color='red', alpha=0.5, label='C0D2(CR=4%)')
plt.plot(years, C3D1_4, linestyle='--', marker='^', markersize=8, color='red', alpha=0.6, label='C3D1(CR=4%)')

# Title and labels
plt.title('Purchase Model - Impact of Churn Rate Levels', fontsize=16)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Risk-adjusted cumulative cost in USD', fontsize=15)

# Format y-axis tick labels as millions
def millions_formatter(x, pos):
    return f'{x / 1e6:.1f}M'

formatter = FuncFormatter(millions_formatter)
plt.gca().yaxis.set_major_formatter(formatter)

# Increase font size of axis ticks
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Legend
plt.legend(fontsize=15, loc='upper left')

# Save the figure in high resolution
plt.savefig('Purchase Model - Impact of Churn Rate.png', dpi=300, bbox_inches='tight')

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Purchase Model - Impact of Compensation Levels

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# Data
years = list(range(6))
C0D2 = [0, 331634.7395, 642059.261, 932726.3724, 1204982.106, 1460074.076]
C3D1_006 = [230840, 421179.4316, 598699.6667, 764327.5889, 918918.5107, 1063262.004]
C3D1_012 = [230840, 437146.1516, 629181.5867, 808005.1453, 974592.1001, 1129841.078]
C3D1_018 = [230840, 453112.8716, 659663.5067, 851682.7016, 1030265.69, 1196420.152]
C3D1_024 = [230840, 469079.5916, 690145.4267, 895360.258, 1085939.279, 1262999.226]

# Plot
plt.figure(figsize=(10, 6))

# Plot lines
plt.plot(years, C0D2, linestyle='-', marker='o', markersize=5, color='black', alpha=0.6, label='C0D2')
plt.plot(years, C3D1_006, linestyle='--', marker='^', markersize=8, color='orange', alpha=0.6, label='C3D1 (CPP=$0.06)')
plt.plot(years, C3D1_012, linestyle='--', marker='^', markersize=8, color='green', alpha=0.6, label='C3D1 (CPP=$0.12)')
plt.plot(years, C3D1_018, linestyle='--', marker='^', markersize=8, color='red', alpha=0.6, label='C3D1 (CPP=$0.18)')
plt.plot(years, C3D1_024, linestyle='--', marker='^', markersize=8, color='blue', alpha=0.6, label='C3D1 (CPP=$0.24)')

# Title and labels
plt.title('Purchase Model - Impact of Compensation Levels', fontsize=16)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Risk-adjusted cumulative cost in USD', fontsize=15)

# Increase font size of axis ticks
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Format y-axis tick labels as millions
def millions_formatter(x, pos):
    return f'{x / 1e6:.1f}M'

formatter = FuncFormatter(millions_formatter)
plt.gca().yaxis.set_major_formatter(formatter)

# Legend
plt.legend(fontsize=15)

# Save the figure in high resolution
plt.savefig('Purchase Model - Impact of Compensation Levels.png', dpi=300, bbox_inches='tight')

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Subscription Model - Impact of Compensation Levels

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# Data
years = list(range(6))
C0D2 = [0, 331634.7395, 642059.261, 932726.3724, 1204982.106, 1460074.076]
C3D1_006 = [125420, 346850.3407, 552635.0386, 743957.927, 921907.9089, 1087486.911]
C3D1_012 = [125420, 362817.0607, 583116.9586, 787635.4834, 977581.4984, 1154065.985]
C3D1_018 = [125420, 378783.7807, 613598.8786, 831313.0397, 1033255.088, 1220645.059]
C3D1_024 = [125420, 394750.5007, 644080.7986, 874990.5961, 1088928.677, 1287224.133]

# Plot
plt.figure(figsize=(10, 6))

# Plot lines
plt.plot(years, C0D2, linestyle='-', marker='o', markersize=5, color='black', alpha=0.6, label='C0D2')
plt.plot(years, C3D1_006, linestyle='--', marker='^', markersize=8, color='orange', alpha=0.6, label='C3D1 (CPP=$0.06)')
plt.plot(years, C3D1_012, linestyle='--', marker='^', markersize=8, color='green', alpha=0.6, label='C3D1 (CPP=$0.12)')
plt.plot(years, C3D1_018, linestyle='--', marker='^', markersize=8, color='red', alpha=0.6, label='C3D1 (CPP=$0.18)')
plt.plot(years, C3D1_024, linestyle='--', marker='^', markersize=8, color='blue', alpha=0.6, label='C3D1 (CPP=$0.24)')

# Title and labels
plt.title('Subscription Model - Impact of Compensation Levels', fontsize=16)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Risk-adjusted cumulative cost in USD', fontsize=15)

# Increase font size of axis ticks
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Format y-axis tick labels as millions
def millions_formatter(x, pos):
    return f'{x / 1e6:.1f}M'

formatter = FuncFormatter(millions_formatter)
plt.gca().yaxis.set_major_formatter(formatter)

# Legend
plt.legend(fontsize=15)

# Save the figure in high resolution
plt.savefig('Subscription Model - Impact of Compensation Levels.png', dpi=300, bbox_inches='tight')

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Subscription Model - Impact of Participation Levels

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# Data
years = list(range(6))
C0D2 = [0, 331634.7395, 642059.261, 932726.3724, 1204982.106, 1460074.076]
C3D1_52 = [125420, 378901.2098, 613823.0615, 831634.2715, 1033664.546, 1221134.723]
C3D1_65 = [125420, 370859.1353, 598470.01, 809634.8774, 1005623.022, 1187600.354]
C3D1_78 = [125420, 362817.0607, 583116.9586, 787635.4834, 977581.4984, 1154065.985]
C3D1_92 = [125420, 354156.365, 566582.9032, 763943.8282, 947382.9344, 1117952.05]

# Plot
plt.figure(figsize=(10, 6))

# Plot lines
plt.plot(years, C0D2, linestyle='-', marker='o', markersize=5, color='black', alpha=0.6, label='C0D2')
plt.plot(years, C3D1_52, linestyle='--', marker='^', markersize=8, color='orange', alpha=0.6, label='C3D1 (f=52%)')
plt.plot(years, C3D1_65, linestyle='--', marker='^', markersize=8, color='green', alpha=0.6, label='C3D1 (f=65%)')
plt.plot(years, C3D1_78, linestyle='--', marker='^', markersize=8, color='red', alpha=0.6, label='C3D1 (f=78%)')
plt.plot(years, C3D1_92, linestyle='--', marker='^', markersize=8, color='blue', alpha=0.6, label='C3D1 (f=92%)')

# Title and labels
plt.title('Subscription Model - Impact of Participation Levels', fontsize=16)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Risk-adjusted cumulative cost in USD', fontsize=15)

# Increase font size of axis ticks
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Format y-axis tick labels as millions
def millions_formatter(x, pos):
    return f'{x / 1e6:.1f}M'

formatter = FuncFormatter(millions_formatter)
plt.gca().yaxis.set_major_formatter(formatter)

# Legend
plt.legend(fontsize=15)

# Save the figure in high resolution
plt.savefig('Subscription Model - Impact of Participation Levels.png', dpi=300, bbox_inches='tight')

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Purchase Model - Impact of Participation Levels

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# Data
years = list(range(6))
C0D2 = [0, 331634.7395, 642059.261, 932726.3724, 1204982.106, 1460074.076]
C3D1_52 = [230840, 453230.3007, 659887.6896, 852003.9334, 1030675.147, 1196909.815]
C3D1_65 = [230840, 445188.2262, 644534.6381, 830004.5393, 1002633.624, 1163375.447]
C3D1_78 = [230840, 437146.1516, 629181.5867, 808005.1453, 974592.1001, 1129841.078]
C3D1_92 = [230840, 428485.4559, 612647.5313, 784313.4902, 944393.5361, 1093727.142]

# Plot
plt.figure(figsize=(10, 6))

# Plot lines
plt.plot(years, C0D2, linestyle='-', marker='o', markersize=5, color='black', alpha=0.6, label='C0D2')
plt.plot(years, C3D1_52, linestyle='--', marker='^', markersize=8, color='orange', alpha=0.6, label='C3D1 (f=52%)')
plt.plot(years, C3D1_65, linestyle='--', marker='^', markersize=8, color='green', alpha=0.6, label='C3D1 (f=65%)')
plt.plot(years, C3D1_78, linestyle='--', marker='^', markersize=8, color='red', alpha=0.6, label='C3D1 (f=78%)')
plt.plot(years, C3D1_92, linestyle='--', marker='^', markersize=8, color='blue', alpha=0.6, label='C3D1 (f=92%)')

# Title and labels
plt.title('Purchase Model - Impact of Participation Levels', fontsize=16)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Risk-adjusted cumulative cost in USD', fontsize=15)

# Increase font size of axis ticks
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Format y-axis tick labels as millions
def millions_formatter(x, pos):
    return f'{x / 1e6:.1f}M'

formatter = FuncFormatter(millions_formatter)
plt.gca().yaxis.set_major_formatter(formatter)

# Legend
plt.legend(fontsize=15)

# Save the figure in high resolution
plt.savefig('Purchase Model - Impact of Participation Levels.png', dpi=300, bbox_inches='tight')

# Show plot
plt.tight_layout()
plt.show()
